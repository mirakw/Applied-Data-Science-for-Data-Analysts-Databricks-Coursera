# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Hyperparameter Search Lab
#
# **Objective**: *Apply grid-search hyperparameter optimization to improve the performance of a model.*
#
# In this lab, you will apply what you've learned in this lesson. When complete, please use the answers to the exercises to answer questions in the following quiz within Coursera.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# -sandbox
#
# ## Exercise 1
#
# In this exercise, you will create an enhanced user-level table to try to better predict whether or not each user takes at least 10,000 steps in a day.
#
# Fill in the blanks in the below cell to create the `adsda.ht_user_metrics_hs_lab` table.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** Refer back to previous demos on how to create the `steps_10000` column.

# %%
# %sql
-- ANSWER
CREATE OR REPLACE TABLE adsda.ht_user_metrics_hs_lab
USING DELTA LOCATION "/adsda/ht-user-metrics-hs-lab" AS (
  SELECT min(resting_heartrate) AS min_resting_heartrate,
         avg(resting_heartrate) AS avg_resting_heartrate,
         max(resting_heartrate) AS max_resting_heartrate,
         max(resting_heartrate) - min(resting_heartrate) AS resting_heartrate_change,
         min(active_heartrate) AS min_active_heartrate,
         avg(active_heartrate) AS avg_active_heartrate,
         max(active_heartrate) AS max_active_heartrate,
         max(active_heartrate) - min(active_heartrate) AS active_heartrate_change,
         min(bmi) AS min_bmi,
         avg(bmi) AS avg_bmi,
         max(bmi) AS max_bmi,
         max(bmi) - min(bmi) AS bmi_change,
         min(vo2) AS min_vo2,
         avg(vo2) AS avg_vo2,
         max(vo2) AS max_vo2,
         max(vo2) - min(vo2) AS vo2_change,
         min(workout_minutes) AS min_workout_minutes,
         avg(workout_minutes) AS avg_workout_minutes,
         max(workout_minutes) AS max_workout_minutes,
         max(workout_minutes) - min(workout_minutes) AS workout_minutes_change,
         CASE WHEN avg(steps) >= 10000 THEN 1 ELSE 0 END AS steps_10000
  FROM adsda.ht_daily_metrics
  GROUP BY device_id
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * 
FROM adsda.ht_user_metrics_hs_lab
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_resting_heartrate</th><th>avg_resting_heartrate</th><th>max_resting_heartrate</th><th>resting_heartrate_change</th><th>min_active_heartrate</th><th>avg_active_heartrate</th><th>max_active_heartrate</th><th>active_heartrate_change</th><th>min_bmi</th><th>avg_bmi</th><th>max_bmi</th><th>bmi_change</th><th>min_vo2</th><th>avg_vo2</th><th>max_vo2</th><th>vo2_change</th><th>min_workout_minutes</th><th>avg_workout_minutes</th><th>max_workout_minutes</th><th>workout_minutes_change</th><th>steps_10000</th></tr></thead><tbody><tr><td>100.12190323385116</td><td>82.68379727873081</td><td>99.13828099149359</td><td>-0.9836222423575691</td><td>120.30779135992243</td><td>139.43487473206162</td><td>162.34782728523246</td><td>42.04003592531002</td><td>19.530815683202114</td><td>22.398063650890794</td><td>24.997081438324194</td><td>5.46626575512208</td><td>20.28334129074003</td><td>20.99401157735923</td><td>21.491176274984294</td><td>1.2078349842442648</td><td>1.0469302273257908</td><td>5.5026324666656405</td><td>9.325750004894761</td><td>8.27881977756897</td><td>0</td></tr><tr><td>52.71287564903336</td><td>77.73294228506452</td><td>97.93773119202254</td><td>45.22485554298918</td><td>109.04938651327842</td><td>127.05715346661702</td><td>146.86986814834722</td><td>37.8204816350688</td><td>22.63526877190205</td><td>25.150812654086298</td><td>27.93361433865782</td><td>5.298345566755767</td><td>24.929150796942785</td><td>25.52747526955064</td><td>26.231702127031934</td><td>1.3025513300891483</td><td>12.109056090051782</td><td>37.2167018100805</td><td>66.11591853237638</td><td>54.0068624423246</td><td>0</td></tr><tr><td>100.37366097806768</td><td>86.51162895591307</td><td>99.78933645583436</td><td>-0.5843245222333167</td><td>129.5517281106538</td><td>147.31573126952208</td><td>177.78314996951866</td><td>48.23142185886485</td><td>16.84474064400951</td><td>19.148256000462478</td><td>21.339664540140973</td><td>4.494923896131464</td><td>18.81713072211899</td><td>19.448406520026342</td><td>19.946846814093323</td><td>1.129716091974334</td><td>10.524606159589158</td><td>45.00008651086257</td><td>84.72505622254651</td><td>74.20045006295736</td><td>0</td></tr><tr><td>58.41880559722201</td><td>77.55054135762612</td><td>98.87532936858241</td><td>40.4565237713604</td><td>110.84551702943472</td><td>129.5770039396946</td><td>146.7386499653505</td><td>35.89313293591579</td><td>21.33582041108623</td><td>24.240375728856797</td><td>26.909149799032416</td><td>5.573329387946185</td><td>20.705859570960108</td><td>21.40130178285617</td><td>22.088526447872425</td><td>1.3826668769123174</td><td>11.402530422658407</td><td>37.886068725488464</td><td>68.11952462786931</td><td>56.7169942052109</td><td>0</td></tr><tr><td>49.81689070901131</td><td>68.93310580458204</td><td>92.68678860925904</td><td>42.86989790024773</td><td>116.68894230853843</td><td>136.50268661405897</td><td>162.3638297702582</td><td>45.67488746171978</td><td>27.4860355505171</td><td>30.726595797380472</td><td>33.87217279937333</td><td>6.38613724885623</td><td>28.102425066324887</td><td>28.855230169253637</td><td>29.7652881606717</td><td>1.6628630943468146</td><td>11.659988588325357</td><td>32.24198398599063</td><td>60.51374198315488</td><td>48.853753394829525</td><td>0</td></tr><tr><td>47.35569868189229</td><td>69.31244794850774</td><td>92.76249605385787</td><td>45.40679737196558</td><td>147.8761660158842</td><td>167.18585016710105</td><td>186.28361490243202</td><td>38.407448886547826</td><td>23.589288180958636</td><td>27.1326690342849</td><td>31.02646723458486</td><td>7.437179053626224</td><td>30.032977706533124</td><td>30.939205114246853</td><td>32.02682828439313</td><td>1.9938505778600089</td><td>0.8561243193074577</td><td>5.119426899323105</td><td>9.947677458057841</td><td>9.091553138750383</td><td>0</td></tr><tr><td>43.51461112051503</td><td>64.64397544858174</td><td>82.0738185611225 ...

# %% [markdown]
# **Coursera Quiz:** How many users in `adsda.ht_user_metrics_hs_lab` take, on average, 10,000 steps per day?

# %%
# %sql
SELECT steps_10000, count(*) FROM adsda.ht_user_metrics_hs_lab GROUP BY steps_10000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>steps_10000</th><th>count(1)</th></tr></thead><tbody><tr><td>1</td><td>1892</td></tr><tr><td>0</td><td>1108</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# ## Exercise 2
#
# In this exercise, you will split your data into a training set (`train_df`), validation set (`val_df`), and test set (`test_df`).
#
# Fill in the blanks below to split your data.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** Refer to the previous demo for guidance.

# %%
# ANSWER
from sklearn.model_selection import train_test_split

ht_user_metrics_pd_df = spark.table("adsda.ht_user_metrics_hs_lab").toPandas()

train_val_df, test_df = train_test_split(ht_user_metrics_pd_df, train_size=0.85, test_size=0.15, random_state=42)
train_df, val_df = train_test_split(train_val_df, train_size=0.7, test_size=0.3, random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz:** How many rows are in the `val_df` DataFrame?

# %%
val_df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: (765, 21)</div>

# %% [markdown]
# ## Exercise 3
#
# In this exercise, you will prepare your random forest classifier.
#
# Fill in the blanks below to complete the task.

# %%
# ANSWER
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 4
#
# In this exercise, you will create a hyperparameter grid to use during the grid search process.
#
# Use the following hyperparameter values:
#
# 1. `max_depth`: 2, 3, 5, 8, 10, 15
# 1. `n_estimators`: 5, 10, 25, 50, 100, 250
# 1. `min_samples_split`: 2, 3, 4
# 1. `min_impurity_decrease`: 0.0, 0.01, 0.05
#
# Fill in the blanks below to create the grid.

# %%
# ANSWER
parameter_grid = {
  "max_depth": [2, 3, 5, 8, 10, 15],
  "n_estimators": [5, 10, 25, 50, 100, 250],
  "min_samples_split": [2, 3, 4],
  "min_impurity_decrease": [0.0, 0.01, 0.05]
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz**: How many total unique combinations of hyperparameters are there in `parameter_grid`?

# %%
len(parameter_grid["max_depth"]) * len(parameter_grid["n_estimators"]) * len(parameter_grid["min_samples_split"]) * len(parameter_grid["min_impurity_decrease"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 324</div>

# %% [markdown]
# ## Exercise 5
#
# In this exercise, you will create a predefined split for your training set and your validation set.
#
# Fill in the blanks below to create the PredefinedSplit.

# %%
# ANSWER
from sklearn.model_selection import PredefinedSplit

# Create list of -1s for training set row or 0s for validation set row
split_index = [-1 if row in train_df.index else 0 for row in train_val_df.index]

# Create predefined split object
predefined_split = PredefinedSplit(test_fold=split_index)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz**: How many 0s are there in `split_index`?

# %%
split_index.count(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: 765</div>

# %% [markdown]
# ## Exercise 6
#
# In this exercise, you will create the grid search object that you will use to optimize your hyperparameter values.
#
# Fill in the blanks below to create the object.

# %%
# ANSWER
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(estimator=rfc, cv=predefined_split, param_grid=parameter_grid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 7
#
# In this exercise, you will fit the grid search process.
#
# Fill in the blanks below to perform the grid search process.

# %%
# ANSWER
grid_search.fit(train_val_df.drop("steps_10000", axis=1), train_val_df["steps_10000"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ..., -1,  0])),
#              error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion=&#39;gini&#39;, max_depth=None,
#                                               max_features=&#39;auto&#39;,
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weigh...0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid=&#39;deprecated&#39;, n_jobs=None,
#              param_grid={&#39;max_depth&#39;: [2, 3, 5, 8, 10, 15],
#                          &#39;min_impurity_decrease&#39;: [0.0, 0.01, 0.05],
#                          &#39;min_samples_split&#39;: [2, 3, 4],
#                          &#39;n_estimators&#39;: [5, 10, 25, 50, 100, 250]},
#              pre_dispatch=&#39;2*n_jobs&#39;, refit=True, return_train_score=False,
#              scoring=None, verbose=0)</div>

# %% [markdown]
# -sandbox
# **Coursera Quiz**: How many unique models are being trained by the grid search process?
#
# * 324
# * 765
# * 325
# * 766
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** Consider the number of unique feature combinations and the final retraining of the model on the training *and* validation sets.

# %% [markdown]
# ## Exercise 8
#
# In this exercise, you will identify the optimal hyperparameter values.
#
# Fill in the blanks below to indentify the optimal hyperparameter values.

# %%
# ANSWER
grid_search.best_params_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: {&#39;max_depth&#39;: 8,
#  &#39;min_impurity_decrease&#39;: 0.0,
#  &#39;min_samples_split&#39;: 3,
#  &#39;n_estimators&#39;: 25}</div>

# %% [markdown]
# **Coursera Quiz:** What is the optimal hyperparameter value for `min_samples_split` according to the grid search process?

# %% [markdown]
# ## Exercise 9
#
# In this exercise, you will identify the validation accuracy that was achieved for the optimal hyperparameter values when trained on the training set.
#
# Fill in the blanks below to identify the validation accuracy.

# %%
# ANSWER
grid_search.best_score_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 0.9882352941176471</div>

# %% [markdown]
# **Coursera Quiz:** What is the best validation set accuracy?

# %% [markdown]
# ## Exercise 10
#
# In this exercise, you will identify the test accuracy achieved by the final, refit model.
#
# Fill in the blanks below to identify the test accuracy.

# %%
# ANSWER
from sklearn.metrics import accuracy_score

accuracy_score(
  test_df["steps_10000"], 
  grid_search.predict(test_df.drop("steps_10000", axis=1))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: 1.0</div>

# %% [markdown]
# **Coursera Quiz:** What is the test set accuracy?

# %% [markdown]
# Congrats! That concludes our lesson on hyperparameter optimization!
#
# Be sure to submit your quiz answers to Coursera, and join us in the next module to learn about how to improve the process even further using cross-validation.

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
