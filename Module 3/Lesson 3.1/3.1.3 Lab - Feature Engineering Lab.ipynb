# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Feature Engineering Lab
#
# **Objective**: *Apply feature engineering to a dataset to derive more meaningful features and improve predictions.*
#
# In this lab, you will apply what you've learned in this lesson. When complete, please use the answers to the exercises to answer questions in the following quiz within Coursera.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res5: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res6: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res7: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Exercise 1
#
# In this exercise, you will create a user-level table with the following columns:
#
# 1. `avg_resting_heartrate` – the average resting heartrate
# 1. `avg_active_heartrate` - the average active heartrate
# 1. `avg_bmi` – the average BMI
# 1. `avg_vo2` - the average oxygen volume
# 1. `sum_workout_minutes` - the sum of total workout minutes
# 1. `sum_steps` - the sum of total steps
#
# Fill in the blanks in the below cell to create the `adsda.ht_user_metrics_lab` table.

# %%
# %sql
-- ANSWER
CREATE OR REPLACE TABLE adsda.ht_user_metrics_lifestyle
USING DELTA LOCATION "/adsda/ht-user-metrics-lifestyle" AS (
  SELECT avg(resting_heartrate) AS avg_resting_heartrate,
         avg(active_heartrate) AS avg_active_heartrate,
         avg(bmi) AS avg_bmi,
         avg(vo2) AS avg_vo2,
         avg(workout_minutes) AS avg_workout_minutes,
         avg(steps) AS avg_steps,
         first(lifestyle) AS lifestyle
  FROM adsda.ht_daily_metrics
  GROUP BY device_id
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT *
FROM adsda.ht_user_metrics_lifestyle
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_resting_heartrate</th><th>avg_active_heartrate</th><th>avg_bmi</th><th>avg_vo2</th><th>avg_workout_minutes</th><th>avg_steps</th><th>lifestyle</th></tr></thead><tbody><tr><td>82.68379727873081</td><td>139.43487473206162</td><td>22.398063650890794</td><td>20.99401157735923</td><td>5.5026324666656405</td><td>5171.495890410959</td><td>Sedentary</td></tr><tr><td>77.73294228506452</td><td>127.05715346661702</td><td>25.150812654086298</td><td>25.52747526955064</td><td>37.2167018100805</td><td>7115.591780821917</td><td>Weight Trainer</td></tr><tr><td>86.51162895591307</td><td>147.31573126952208</td><td>19.148256000462478</td><td>19.448406520026342</td><td>45.00008651086257</td><td>7257.693150684931</td><td>Weight Trainer</td></tr><tr><td>77.55054135762612</td><td>129.5770039396946</td><td>24.240375728856797</td><td>21.40130178285617</td><td>37.886068725488464</td><td>7129.690410958904</td><td>Weight Trainer</td></tr><tr><td>68.93310580458204</td><td>136.50268661405897</td><td>30.726595797380472</td><td>28.855230169253637</td><td>32.24198398599063</td><td>6958.378082191781</td><td>Weight Trainer</td></tr><tr><td>69.31244794850774</td><td>167.18585016710105</td><td>27.1326690342849</td><td>30.939205114246853</td><td>5.119426899323105</td><td>5128.024657534246</td><td>Sedentary</td></tr><tr><td>64.64397544858174</td><td>152.9654977304546</td><td>29.17716498363452</td><td>28.92795344089978</td><td>5.015081852287961</td><td>5167.789041095891</td><td>Sedentary</td></tr><tr><td>81.33282756113321</td><td>137.57131998347788</td><td>20.850071485672633</td><td>22.564006304582495</td><td>42.375521457262316</td><td>7281.586301369863</td><td>Weight Trainer</td></tr><tr><td>64.79507042723496</td><td>139.39836367080545</td><td>31.386431213715433</td><td>29.096510773429188</td><td>33.3298371336183</td><td>7029.608219178082</td><td>Weight Trainer</td></tr><tr><td>89.51117796589962</td><td>126.57048164605168</td><td>19.830753716401606</td><td>19.750462151303648</td><td>43.30528046136424</td><td>7362.769863013698</td><td>Weight Trainer</td></tr><tr><td>86.21818958751346</td><td>144.21087862838124</td><td>22.52778323930918</td><td>21.78708318013077</td><td>39.785471045450805</td><td>7112.378082191781</td><td>Weight Trainer</td></tr><tr><td>87.30070759200832</td><td>139.97122582181592</td><td>20.119256489777136</td><td>19.489433743595434</td><td>6.021529754625338</td><td>5177.780821917808</td><td>Sedentary</td></tr><tr><td>89.79743806208528</td><td>152.631637108012</td><td>17.76383666815434</td><td>19.07515065992139</td><td>6.746997303777693</td><td>5188.791780821918</td><td>Sedentary</td></tr><tr><td>84.03137470273838</td><td>150.56703733080104</td><td>21.540962942918842</td><td>22.15966551690082</td><td>5.816435881132796</td><td>5166.986301369863</td><td>Sedentary</td></tr><tr><td>80.1338443085794</td><td>139.1112118995804</td><td>21.160221790913127</td><td>21.02444985599776</td><td>40.90915905690374</td><td>7123.101369863014</td><td>Weight Trainer</td></tr><tr><td>63.81019197505969</td><td>127.98945894646793</td><td>29.768767735751247</td><td>31.84391549028476</td><td>34.58598632723298</td><td>7030.761643835616</td><td>Weight Trainer</td></tr><tr><td>80.8985477248526</td><td>133.876183209391</td><td>23.439743707576</td><td>22.215220710177448</td><td>37.98228032886922</td><td>7139.391780821918</td><td>Weight Trainer</td></tr><tr><td>75.74981399738974</td><td>130.93270399176032</td><td>22.035605849593626</td><td>25.10970186960966</td><td>43.6095186878573</td><td>10870.605479452055</td><td>Athlete</td></tr><tr><td>74.80771257625209</td><td>147.73504483488392</td><td>27.447509711490927</td><td>27.409653663273698</td><td>35.34943781656176</td><td>6988.13698630137</td><td>Weight Trainer</td></tr><tr><td>60.12813834027657</td><td>119.2243293003114</td><td>30.787674339113707</td><td>32.12788120767524</td><td>34.15499959666808</td><td>9960. ...

# %% [markdown]
# **Coursera Quiz:** Why did we run a `group by`?

# %%
import numpy as np
np.random.seed(0)
df = spark.table("adsda.ht_user_metrics_lifestyle").toPandas()
df.loc[df.sample(frac=0.18).index, 'avg_bmi'] = np.nan
df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: (3000, 7)</div>

# %% [markdown]
# -sandbox
# ## Exercise 2
#
# In this exercise, you will split your data into an training set and an inference set.
#
# Fill in the blanks below to split the data.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> In practice, you should use as much data as possible for your training set. An inference set will usually become available after the training process, rather than being split apart from your training set prior to the training of the model.

# %%
# ANSWER
from sklearn.model_selection import train_test_split

train_df, inference_df = train_test_split(df, train_size=0.85, test_size=0.15, random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz:** How many rows have missing values in the `avg_bmi` column in the training set?

# %%
# ANSWER
train_df.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: avg_resting_heartrate      0
# avg_active_heartrate       0
# avg_bmi                  466
# avg_vo2                    0
# avg_workout_minutes        0
# avg_steps                  0
# lifestyle                  0
# dtype: int64</div>

# %% [markdown]
# ## Exercise 3
#
# In this exercise, you'll fill the `avg_bmi` with the median.
#
# Fill in the blanks below to complete the task.

# %%
# ANSWER
import pandas as pd

avg_bmi_median = train_df['avg_bmi'].median()

train_df['avg_bmi'] = train_df['avg_bmi'].fillna(avg_bmi_median)
inference_df['avg_bmi'] = inference_df['avg_bmi'].fillna(avg_bmi_median)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1608173151747-0/PythonShell.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # [ML-9441] We keep this launch script minimal because all classes and methods defined here are
# /local_disk0/tmp/1608173151747-0/PythonShell.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # registered under __main__, which will be replaced by a dummy module in the interactive shell.
# </div>

# %% [markdown]
# **Coursera Quiz:** What is the value of `avg_bmi_median` rounded to the nearest hundredth place?

# %%
# ANSWER
print(round(avg_bmi_median, 2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">23.01
# </div>

# %% [markdown]
# ## Exercise 4
#
# Scale the `avg_vo2`, using the `train_df` to fit and transform the data.
#
# Fill in the blanks below to complete the task.

# %%
# ANSWER
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
scaled_training_data = sc.fit_transform(train_df[['avg_bmi']])
train_df['avg_bmi_scaled'] = scaled_training_data

scaled_inference_data = sc.transform(inference_df[['avg_bmi']])
inference_df['avg_bmi_scaled'] = scaled_inference_data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1608173151747-0/PythonShell.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # [ML-9441] We keep this launch script minimal because all classes and methods defined here are
# /local_disk0/tmp/1608173151747-0/PythonShell.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == &#39;__main__&#39;:
# </div>

# %% [markdown]
# **Coursera Quiz**: Using the `.min()` method on the original `avg_bmi` and `avg_bmi_scaled` columns, find the difference, rounded to the nearest tenth

# %%
print(inference_df['avg_bmi'].min() - inference_df['avg_bmi_scaled'].min())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">14.617319130584574
# </div>

# %% [markdown]
# ## Exercise 5
#
# In this exercise, you will create one-hot encoded columns on the `lifestyle` column.
#
# Fill in the blanks below to complete the task.

# %%
# ANSWER
train_df = pd.get_dummies(train_df, prefix='ohe', columns=['lifestyle'])
inference_df = pd.get_dummies(inference_df, prefix='ohe', columns=['lifestyle'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz**: How many rows in our training set (`train_df`) have a value of 1 for the column `ohe_Weight Trainer`?

# %%
# ANSWER
train_df[train_df['ohe_Weight Trainer'] > 0].shape[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 657</div>

# %% [markdown]
# ## Exercise 6
#
# Over the next series of exercises, you will fit a Logistic Regression model, utilizing several steps above and a few new ones.
#
# Our target here is the lifestyle column. The cell below will reset our dataframe and also transform the target lifestyle column so that we have a binary classification task.
#
# Fill in the blanks below to complete the task.

# %%
df = spark.table("adsda.ht_user_metrics_lifestyle").toPandas()
df.loc[df.sample(frac=0.18).index, 'avg_workout_minutes'] = np.nan
df['lifestyle'] = df['lifestyle'].map({'Sedentary':0, 'Weight Trainer':1, 'Athlete':1, 'Cardio Enthusiast':1})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz**: How many observations of class `sedentary` do we have in the totality of our dataset?
#
# Write the code in the below cell to answer the question.

# %%
# ANSWER
df["lifestyle"].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 1    2688
# 0     312
# Name: lifestyle, dtype: int64</div>

# %% [markdown]
# ## Exercise 7
#
# In this exercise, you will train-test split the data, using `lifestyle` as the target. Set the test size to be `10%` and the random state to `3`.
#
# Fill in the blanks below to complete the task.

# %%
# ANSWER
from sklearn.model_selection import train_test_split
X = df.drop('lifestyle', axis=1)
y = df['lifestyle']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.1, random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# ## Exercise 8
#
# In this exercise, you will clean up any missing values by imputing with the mean.
#
# Fill in the blanks below to complete the task.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** Recall that we always want to learn values from the training set!

# %%
# ANSWER
avg_wo_minutes_mean = X_train['avg_workout_minutes'].mean()
X_train['avg_workout_minutes'] = X_train['avg_workout_minutes'].fillna(avg_wo_minutes_mean)
X_test['avg_workout_minutes'] = X_test['avg_workout_minutes'].fillna(avg_wo_minutes_mean)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1608173151747-0/PythonShell.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /local_disk0/tmp/1608173151747-0/PythonShell.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Databricks Python Shell
# </div>

# %% [markdown]
# ## Exercise 8
#
# In this exericse, you will scale *all* of the columns.
#
# Fill in the blanks below to complete the task.

# %%
# ANSWER

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 9
#
# In this exercise, you will fit a Logistic Regression model on our target: `lifestyle`.
#
# Fill in the blanks below to complete the task.

# %%
# ANSWER
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train, y_train)

lr.score(X_test, y_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 1.0</div>

# %% [markdown]
# **Coursera Quiz**:
# What might account for our score?

# %% [markdown]
# Congrats! That concludes our lesson on feature engineering!
#
# Be sure to submit your quiz answers to Coursera, and join us in the next lesson to learn about feature selection.

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
