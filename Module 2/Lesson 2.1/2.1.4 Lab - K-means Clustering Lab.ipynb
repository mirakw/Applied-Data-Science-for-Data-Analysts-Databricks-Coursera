# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # K-means Clustering Lab
#
# **Objective**: *Apply K-means clustering to a dataset to learn more about how the records are related to one another.*
#
# In this lab, you will apply what you've learned in this lesson. When complete, please use the answers to the exercises to answer questions in the following quiz within Coursera.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Exercise 1
#
# In this exercise, you will create a user-level table with the following columns:
#
# 1. `avg_resting_heartrate` – the average resting heartrate
# 1. `avg_active_heartrate` - the average active heartrate
# 1. `avg_bmi` – the average BMI
# 1. `avg_vo2` - the average oxygen volume
# 1. `sum_workout_minutes` - the sum of total workout minutes
# 1. `sum_steps` - the sum of total steps
#
# Fill in the blanks in the below cell to create the `adsda.ht_user_metrics_lab` table.

# %%
# %sql

SELECT *
FROM adsda.ht_daily_metrics
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>dte</th><th>resting_heartrate</th><th>active_heartrate</th><th>bmi</th><th>vo2</th><th>workout_minutes</th><th>lifestyle</th><th>steps</th></tr></thead><tbody><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-01</td><td>84.21990807741808</td><td>122.36614513322988</td><td>24.001442078098176</td><td>23.520174244131812</td><td>55.290771176379415</td><td>Athlete</td><td>10345</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-02</td><td>75.56009664616255</td><td>132.08213570805194</td><td>23.981473224271443</td><td>23.241395323502907</td><td>27.99672176043603</td><td>Athlete</td><td>9140</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-03</td><td>67.95214658754116</td><td>133.897419834453</td><td>24.01203323166733</td><td>23.844758959223647</td><td>6.403982740621206</td><td>Athlete</td><td>8895</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-04</td><td>72.07402249362427</td><td>130.27996931348147</td><td>24.184537499965806</td><td>23.65815389509837</td><td>21.06190942499232</td><td>Athlete</td><td>10683</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-05</td><td>84.21089219223238</td><td>130.45737338095134</td><td>24.504363282462865</td><td>23.930176012952693</td><td>11.171669668342071</td><td>Athlete</td><td>8752</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-06</td><td>75.658933279154</td><td>136.26823209734053</td><td>24.880787811951734</td><td>23.515016511789092</td><td>36.322123198181856</td><td>Athlete</td><td>8581</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-07</td><td>77.54221509394144</td><td>127.33802451540777</td><td>23.662747181933334</td><td>23.267727721229672</td><td>23.757184390043182</td><td>Athlete</td><td>6388</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-08</td><td>81.40364010506734</td><td>129.20986100613382</td><td>22.781450746703168</td><td>23.717085048542415</td><td>0.0</td><td>Athlete</td><td>6723</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-09</td><td>81.41987677503842</td><td>124.09827579356201</td><td>24.947920304321936</td><td>23.765823077235936</td><td>37.33242567311174</td><td>Athlete</td><td>9057</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-10</td><td>82.25271399068558</td><td>117.5871148531541</td><td>23.97351606107311</td><td>23.605851911587216</td><td>34.86683134450769</td><td>Athlete</td><td>11495</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-11</td><td>84.28408504932399</td><td>136.1083482831425</td><td>25.886797905977627</td><td>23.26030115411262</td><td>56.35066117427874</td><td>Athlete</td><td>12257</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-12</td><td>63.672073082949886</td><td>114.59185087375721</td><td>22.56413506906228</td><td>23.17213572159388</td><td>55.98356029661769</td><td>Athlete</td><td>12875</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-13</td><td>70.69750462339044</td><td>119.51494673718103</td><td>24.473794571242056</td><td>23.63260638103216</td><td>32.504610586051</td><td>Athlete</td><td>10679</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-14</td><td>80.2805518434975</td><td>140.60149051304072</td><td>24.53246270144892</td><td>23.582643570132053</td><td>19.062362827372276</td><td>Athlete</td><td>8861</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-15</td><td>81.50333006806295</td><td>124.1433880428183</td><td>24.717900539387905</td><td>22.96094434848874</td><td>40.97236298514192</td><td>Athlete</td><td>11828</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-16</td><td>77.74982660037884</td><td>141.0137885000709</td><td>24.20908037313107</td><td>23.349165757910022</td><td>38.15782381812945</td> ...

# %%
# %sql
-- ANSWER
CREATE OR REPLACE TABLE adsda.ht_user_metrics_lab
USING DELTA LOCATION "/adsda/ht-user-metrics-lab" AS (
  SELECT avg(resting_heartrate) AS avg_resting_heartrate,
         avg(active_heartrate) AS avg_active_heartrate,
r><td>87.70207891311685</td><td>140.50505088888457</td><td>20.67371260191408</td><td>20.63694876479251</td><td>2193.3762942679477</td><td>1906160.0</td></tr><tr><td>66.52760200418946</td><td>149.06735467346004</td><td>28.38913981291086</td><td>29.12212055812403</td><td>12670.403105326306</td><td>2570350.0</td></tr><tr><td>88.24288588315338</td><td>134.29493079534137</td><td>18.1656780435617</td><td>18.456347013808923</td><td>17205.808031390294</td><td>2685767.0</td></tr><tr><td>92.13068081119378</td><td>135.37092095546004</td><t ...

# %% [markdown]
# **Coursera Quiz:** How many rows and columns are in `adsda.ht_user_metrics_lab`?

# %%
df = spark.table("adsda.ht_user_metrics_lab").toPandas()
df.shape

# %%
df

# %% [markdown]
# -sandbox
# ## Exercise 2
#
# In this exercise, you will split your data into an training set and an inference set.
#
# Fill in the blanks below to split the data.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> In practice, you should use as much data as possible for your training set. An inference set will usually become available after the training process, rather than being split apart from your training set prior to the training of the model.

# %%
# ANSWER
from sklearn.model_selection import train_test_split

train_df, inference_df = train_test_split(df, train_size=0.85, test_size=0.15, random_state=42)

# %% [markdown]
# **Coursera Quiz:** How many rows are in the training set and the inference set?

# %%
print(f"{train_df.shape[0]} and {inference_df.shape[0]}")

# %% [markdown]
# ## Exercise 3
#
# In this this exercise, you will identify the optimal number of clusters for K-means using the training set.
#
# When completing this exercise:
#
# * Assess values of *K* from 2-16
# * Set the maximum number of iterations to 500
# * Use a random state of 1234
#
# Fill in the blanks below to compute the distortion for each value of *K*.

# %%
# ANSWER
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale

distortions = []
values_of_k = range(2, 16)

for k in values_of_k:
  k_means = KMeans(n_clusters=k, max_iter=500, random_state=1234)
  k_means.fit(scale(train_df))
  distortion = k_means.score(scale(train_df))
  distortions.append(-distortion)

# %% [markdown]
# **Coursera Quiz:** Which of the values of *K* has the lowest level of distortion?

# %%
list(zip(distortions, values_of_k))

# %% [markdown]
# **Coursera Quiz:** According to the elbow method, which of the values of *K* is the optimal number of clusters?

# %%
import matplotlib.pyplot as plt

plt.plot(values_of_k, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.show()

# %% [markdown]
# ## Exercise 4
#
# In this exercise, you will retrain the model with the optimal number of clusters.
#
# Fill in the blanks below to retrain the model.

# %%
# ANSWER
k_means = KMeans(n_clusters=4, max_iter=500, random_state=1234)
k_means.fit(scale(train_df))

# %% [markdown]
# **Coursera Quiz**: Which of the following datasets should be used when retraining the model with the optimal number of clusters? Select one.
#
# * The training set
# * The inference set
# * The full set
# * Data that is not yet available

# %% [markdown]
# ## Exercise 5
#
# In this exercise, you will examine the centroids for the clusters.
#
# Fill in the blanks below to examine the centroids.

# %%
# ANSWER
k_means.cluster_centers_

# %% [markdown]
# **Coursera Quiz**: In how many dimensions is each centroid?
#
# * 2
# * 4
# * 6
# * 16

# %% [markdown]
# ## Exercise 6
#
# In this exercise, you will perform inference by placing new rows from the inference set into the existing clusters.
#
# Fill in the blanks below to assign rows from the inference set into new clusters.

# %%
# ANSWER
inference_df_clusters = k_means.predict(scale(inference_df))
clusters_df = inference_df.copy()
clusters_df["cluster"] = inference_df_clusters

# %% [markdown]
# **Coursera Quiz**: Which of the clusters has the most rows from the inference set assigned to it?

# %%
clusters_df["cluster"].value_counts()

# %% [markdown]
# **Coursera Quiz**: Which of the clusters has the rows that take the greatest number of average total steps?

# %%
clusters_df.groupby(["cluster"])[["sum_steps"]].mean()

# %% [markdown]
# Congrats! That concludes our lesson on K-means clustering!
#
# Be sure to submit your quiz answers to Coursera, and join us in the next lesson to learn about principal components analysis.

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
